# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("tweet_data.csv")
# Out:
# /Users/jialichen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (0,1,2,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#                                                tweet place language  \
# 0  We at In Professional Development join with pe...   NaN       en
# 1  Join us in remembering Her Majesty Queen Eliza...   NaN       en
# 2  "When life seems hard, the courageous do not l...   NaN       en
# 3  We join the nation in mourning the death of He...   NaN       en
# 4  We are saddened by the death of Her Majesty Qu...   NaN       en
#
#    replies_count  retweets_count  likes_count  negative_score  positive_score  \
# 0            0.0             0.0          0.0           0.130           0.128
# 1            0.0             0.0          0.0           0.151           0.136
# 2            0.0             0.0          0.0           0.156           0.260
# 3            0.0             0.0          0.0           0.172           0.144
# 4            1.0             0.0          0.0           0.254           0.056
#
#    neutral_score  compound_score final_tag  counter
# ...

# %%
len(data)
# Out:
# 662747

# %%
new_df = pd.DataFrame()

# %%
new_df['language'] = data['language']

# %%
new_df['score'] = data['compound_score']

# %%
new_df['counter'] = data['counter']

# %%
new_df['score'] = np.round(new_df['score'],2)

# %%
final = new_df.groupby(['score', 'language']).count()

# %%
final
# Out:
#                 counter
# score language
# -0.99 en              4
# -0.98 en             31
# -0.97 de              4
#       en             61
# -0.96 de              1
# ...                 ...
#  0.95 pt              1
#  0.96 en            526
#  0.97 en            343
#  0.98 en            163
#  0.99 en             32
#
# [1396 rows x 1 columns]

# %%
final.reset_index(inplace = True)

# %%
final
# Out:
#       score language  counter
# 0     -0.99       en        4
# 1     -0.98       en       31
# 2     -0.97       de        4
# 3     -0.97       en       61
# 4     -0.96       de        1
# ...     ...      ...      ...
# 1391   0.95       pt        1
# 1392   0.96       en      526
# 1393   0.97       en      343
# 1394   0.98       en      163
# 1395   0.99       en       32
#
# [1396 rows x 3 columns]

# %%
final
# Out:
#       score language  counter
# 0     -0.99       en        4
# 1     -0.98       en       31
# 2     -0.97       de        4
# 3     -0.97       en       61
# 4     -0.96       de        1
# ...     ...      ...      ...
# 1391   0.95       pt        1
# 1392   0.96       en      526
# 1393   0.97       en      343
# 1394   0.98       en      163
# 1395   0.99       en       32
#
# [1396 rows x 3 columns]

# %%
type(final)
df = final

# %%
# df.to_csv("final.csv", encoding='utf-8', index=False)

# %%
df.sort_values('counter', ascending = False)
# Out:
#       score language  counter
# 641    0.00       en    34621
# 277   -0.56       en     7876
# 1055   0.54       en     7805
# 637    0.00       cy     7504
# 224   -0.60       en     7235
# ...     ...      ...      ...
# 852    0.32       pl        1
# 854    0.32      und        1
# 855    0.33       ca        1
# 218   -0.61       zh        1
# 925    0.40       pt        1
#
# [1396 rows x 3 columns]

# %%
language_count = data.groupby('language').count().sort_values('counter', ascending = False)

# %%
language_count.reset_index(inplace = True)
language_count
# Out:
#    language   tweet  place  replies_count  retweets_count  likes_count  \
# 0        en  159530    201         159530          159530       159530
# 1        cy    8583      8           8583            8583         8583
# 2        es    3209      4           3209            3209         3209
# 3       und    3042      4           3042            3042         3042
# 4        fr    1677      1           1677            1677         1677
# ..      ...     ...    ...            ...             ...          ...
# 61       my       1      0              1               1            1
# 62       lo       1      0              1               1            1
# 63       ug       1      0              1               1            1
# 64       hy       1      0              1               1            1
# 65       bg       1      0              1               1            1
#
#     negative_score  positive_score  neutral_score  compound_score  final_tag  \
# ...

# %%
language_count.head(30)
language_include = language_count['language']

# %%
language_include = language_include.head(30)

# %%
language_include
# Out:
# 0      en
# 1      cy
# 2      es
# 3     und
# 4      fr
# 5      de
# 6      in
# 7      ja
# 8      hi
# 9      it
# 10     ar
# 11     pt
# 12     tl
# 13     th
# 14     pl
# 15     zh
# 16     ta
# 17     nl
# 18     ur
# 19     ca
# 20     fa
# 21     el
# 22     bn
# 23     ht
# 24     et
# 25     fi
# 26     mr
# 27    zxx
# 28     ro
# 29     gu
# Name: language, dtype: object

# %%
language_names = ['English', 'Welsh', 'Spanish', 'French', 'German', 'Indonesian', 'Japanese', 'Hindi', 'Italian', 'Arabic', 
                 'Portuguese', 'Tagalog', 'Thai', 'Polish', 'Chinese', 'Tamil', 'Dutch', 'Urdu', 'Catalan', 
                 'Persian', 'Greek', 'Bengali', 'Haitian', 'Estonian', 'Finnish', 'Marathi', 'Romanian', 'Gujarati']

# %%
type(language_include)
# Out:
# pandas.core.series.Series

# %%
language_include = language_include.reset_index(drop = True)

# %%
language_include.pop(3)
# Out:
# 'und'

# %%
language_include
# Out:
# 0      en
# 1      cy
# 2      es
# 4      fr
# 5      de
# 6      in
# 7      ja
# 8      hi
# 9      it
# 10     ar
# 11     pt
# 12     tl
# 13     th
# 14     pl
# 15     zh
# 16     ta
# 17     nl
# 18     ur
# 19     ca
# 20     fa
# 21     el
# 22     bn
# 23     ht
# 24     et
# 25     fi
# 26     mr
# 27    zxx
# 28     ro
# 29     gu
# Name: language, dtype: object

# %%
language_include.pop(27)
# Out:
# 'zxx'

# %%
less_langs = data[data['language'].isin(language_include)]
less_langs
# Out:
#                                                     tweet place language  \
# 0       We at In Professional Development join with pe...   NaN       en
# 1       Join us in remembering Her Majesty Queen Eliza...   NaN       en
# 2       "When life seems hard, the courageous do not l...   NaN       en
# 3       We join the nation in mourning the death of He...   NaN       en
# 4       We are saddened by the death of Her Majesty Qu...   NaN       en
# ...                                                   ...   ...      ...
# 662742  Queen Elizabeth II, Britain's longest-reigning...   NaN       en
# 662743  Queen Elizabeth II dies at age 96  https://t.c...   NaN       en
# 662744  GOD SAVE THE KING !! Today a figure of our his...   NaN       en
# 662745  70 years. ⠀⠀ 15 Prime Ministers. ⠀⠀ 13 America...   NaN       en
# 662746  She wasn't perfect but she was great, an insti...   NaN       en
#
#         replies_count  retweets_count  likes_count  negative_score  \
# ...

# %%
less_langs[less_langs['language'] == 'und']
# Out:
# Empty DataFrame
# Columns: [tweet, place, language, replies_count, retweets_count, likes_count, negative_score, positive_score, neutral_score, compound_score, final_tag, counter]
# Index: []

# %%
less_langs.reset_index(inplace = True, drop = True)

# %%
less_langs
# Out:
#                                                     tweet place language  \
# 0       We at In Professional Development join with pe...   NaN       en
# 1       Join us in remembering Her Majesty Queen Eliza...   NaN       en
# 2       "When life seems hard, the courageous do not l...   NaN       en
# 3       We join the nation in mourning the death of He...   NaN       en
# 4       We are saddened by the death of Her Majesty Qu...   NaN       en
# ...                                                   ...   ...      ...
# 183042  Queen Elizabeth II, Britain's longest-reigning...   NaN       en
# 183043  Queen Elizabeth II dies at age 96  https://t.c...   NaN       en
# 183044  GOD SAVE THE KING !! Today a figure of our his...   NaN       en
# 183045  70 years. ⠀⠀ 15 Prime Ministers. ⠀⠀ 13 America...   NaN       en
# 183046  She wasn't perfect but she was great, an insti...   NaN       en
#
#         replies_count  retweets_count  likes_count  negative_score  \
# ...

# %%
final_df = pd.DataFrame()

# %%
final_df['language'] = less_langs['language']

# %%
final_df['score'] = less_langs['compound_score']

# %%
final_df['counter'] = less_langs['counter']

# %%
final_df['score'] = np.round(final_df['score'],2)

# %%
final_df = final_df.groupby(['score', 'language']).count()

# %%
final_df
# Out:
#                 counter
# score language
# -0.99 en              4
# -0.98 en             31
# -0.97 de              4
#       en             61
# -0.96 de              1
# ...                 ...
#  0.95 pt              1
#  0.96 en            526
#  0.97 en            343
#  0.98 en            163
#  0.99 en             32
#
# [1208 rows x 1 columns]

# %%
final_df.reset_index(inplace = True)

# %%
final_df
# Out:
#       score language  counter
# 0     -0.99       en        4
# 1     -0.98       en       31
# 2     -0.97       de        4
# 3     -0.97       en       61
# 4     -0.96       de        1
# ...     ...      ...      ...
# 1203   0.95       pt        1
# 1204   0.96       en      526
# 1205   0.97       en      343
# 1206   0.98       en      163
# 1207   0.99       en       32
#
# [1208 rows x 3 columns]

# %%
final_df
# Out:
#       score language  counter
# 0     -0.99       en        4
# 1     -0.98       en       31
# 2     -0.97       de        4
# 3     -0.97       en       61
# 4     -0.96       de        1
# ...     ...      ...      ...
# 1203   0.95       pt        1
# 1204   0.96       en      526
# 1205   0.97       en      343
# 1206   0.98       en      163
# 1207   0.99       en       32
#
# [1208 rows x 3 columns]

# %%
df = final_df

# %%
# df.to_csv("clean_final.csv", encoding='utf-8', index=False)

# %%
lan = df['language'].unique()

# %%
len(lan)
# Out:
# 28

# %%
df
# Out:
#       score language  counter
# 0     -0.99       en        4
# 1     -0.98       en       31
# 2     -0.97       de        4
# 3     -0.97       en       61
# 4     -0.96       de        1
# ...     ...      ...      ...
# 1203   0.95       pt        1
# 1204   0.96       en      526
# 1205   0.97       en      343
# 1206   0.98       en      163
# 1207   0.99       en       32
#
# [1208 rows x 3 columns]

# %%
totals = pd.DataFrame(data.groupby('language').counter.sum())

# %%
totals.reset_index(inplace = True)

# %%
totals = totals.rename(columns={"counter": "total_counter"})

# %%
new = df.merge(totals, on= 'language')

# %%
new
# Out:
#       score language  counter  total_counter
# 0     -0.99       en        4       159530.0
# 1     -0.98       en       31       159530.0
# 2     -0.97       en       61       159530.0
# 3     -0.96       en       67       159530.0
# 4     -0.95       en       90       159530.0
# ...     ...      ...      ...            ...
# 1203   0.64       th        1          362.0
# 1204   0.65       th        2          362.0
# 1205   0.00       gu       48           50.0
# 1206   0.44       gu        1           50.0
# 1207   0.54       gu        1           50.0
#
# [1208 rows x 4 columns]

# %%
new['score'].std()
# Out:
# 0.5523611494277231

# %%
column='score'
new_column = "new_score"

# %%
new[new_column] = new[column] /new[column].abs().max()

# %%
new['new_score'].std()
# Out:
# 0.5579405549774967
